# %% [markdown]
# ### income

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/income.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 第５表　各種世帯別にみた所得金額階級別世帯数の分布及び中央値 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         NaN                            NaN        NaN        NaN        NaN
# 1         NaN                    所 得 金 額 階 級        全世帯        NaN      高齢者世帯
# 2         NaN                            NaN     累積度数分布     相対度数分布     累積度数分布
# 3         NaN                            NaN        （％）        （％）        （％）
# 4         NaN                       総　　　　　　数      　   ・     100.0       　   ・
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7      Unnamed: 8 Unnamed: 9  Unnamed: 10  \
# 0        NaN        NaN        NaN             NaN    平成27年調査          NaN
# 1        NaN    児童のいる世帯        NaN  65歳以上の者の\nいる世帯        NaN          NaN
# 2     相対度数分布     累積度数分布     相対度数分布          累積度数分布     相対度数分布          NaN
# 3        （％）        （％）        （％）             （％）        （％）          NaN
# 4     100.0       　   ・     100.0            　   ・     100.0           NaN
#
#    Unnamed: 11  Unnamed: 12
# ...
